# %%
#Machine Learning:- In-class programming assignment 2

# %%
#Problem 1
import numpy as np
array=np.random.randint(1,20,(1,15))
print("Random array:")
print(array)
array=np.reshape(array,(3,5))
print("1.Reshaped array to 3 by 5:")
print(array)
print("2.Shape of reshaped array:")
print(array.shape)
for i in array:
    i[np.where(i==i.max())]=0
print("3.Modified array to replace the max in each row by 0:")
print(array)
# Out:
# Random array:
# [[18 12 19 12  4 15  6 17  8  7  1 17  3 12  5]]
# 1.Reshaped array to 3 by 5:
# [[18 12 19 12  4]
#  [15  6 17  8  7]
#  [ 1 17  3 12  5]]
# 2.Shape of reshaped array:
# (3, 5)
# 3.Modified array to replace the max in each row by 0:
# [[18 12  0 12  4]
#  [15  6  0  8  7]
#  [ 1  0  3 12  5]]

# %%
#Problem 2
#2.1
import pandas as pd
df=pd.read_csv("data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#2.2
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
#2.3.1
df.isnull().any()
# Out:
# Duration    False
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
#2.3.2
df.fillna(df.mean(), inplace=True)
df.isnull().any()
# Out:
# Duration    False
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
#2.4
df.agg({'Duration':['min','max','count','mean'],'Pulse':['min','max','count','mean']})
# Out:
#          Duration       Pulse
# min     15.000000   80.000000
# max    300.000000  159.000000
# count  169.000000  169.000000
# mean    63.846154  107.461538

# %%
#2.5
df.loc[(df['Calories']>500)&(df['Calories']<1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#2.6
df.loc[(df['Calories']>500)&(df['Pulse']<100)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
#2.7
df_modified = df[['Duration','Pulse','Calories']]
df_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#2.8
del df['Maxpulse']

# %%
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
#2.9
df['Calories'] = df['Calories'].astype(np.int64)
df.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
#2.10
df.plot.scatter(x='Duration',y='Calories',c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %%
#Problem 3
import matplotlib.pyplot as plt
import numpy as np

y = np.array([22.2, 17.6, 8.8, 8, 7.7, 6.7])
mylabels = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
myexplode = [0.2, 0, 0, 0,0,0]
plt.pie(y,labels=mylabels, explode = myexplode,autopct='%1.1f%%',startangle=140)
plt.show()
